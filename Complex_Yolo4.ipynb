# %% [markdown]
# # Install the pretrained Yolo Complex 4 Model

# %%
# !pip install --upgrade --no-cache-dir gdown
# !gdown  https://drive.google.com/uc?id=1jHSmqVng7Z8052eNs3BvuwE5zC-IJD7f
# Out:
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.4.0-py3-none-any.whl size=14774 sha256=bc947b7968fb6eb6a3e689aa70d8e9d7c5533d8ab4857c8f0b9953daae8cc02d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ebr2lmw6/wheels/fb/c3/0e/c4d8ff8bfcb0461afff199471449f642179b74968c15b7a69c
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.2.2
#     Uninstalling gdown-4.2.2:
#       Successfully uninstalled gdown-4.2.2
# ...
# Downloading...
# From: https://drive.google.com/uc?id=1jHSmqVng7Z8052eNs3BvuwE5zC-IJD7f
# To: /content/Complex-YOLOv4-Pytorch.rar
# 100% 475M/475M [00:05<00:00, 89.5MB/s]

# %%
# !unrar  x /content/Complex-YOLOv4-Pytorch.rar -d /content
# Out:
# UNRAR 5.50 freeware      Copyright (c) 1993-2017 Alexander Roshal
#
#
# Extracting from /content/Complex-YOLOv4-Pytorch.rar
#
# Creating    /content/Complex-YOLOv4-Pytorch                           OK
#   OK
# Creating    /content/Complex-YOLOv4-Pytorch/checkpoints               OK
#   OK
# Creating    /content/Complex-YOLOv4-Pytorch/dataset                   OK
# Creating    /content/Complex-YOLOv4-Pytorch/dataset/kitti             OK
#   OK
# Creating    /content/Complex-YOLOv4-Pytorch/dataset/kitti/ImageSets   OK
#   OK
#   OK
#   OK
# Creating    /content/Complex-YOLOv4-Pytorch/dataset/kitti/testing     OK
# Creating    /content/Complex-YOLOv4-Pytorch/dataset/kitti/testing/calib  OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# %cd /content/Complex-YOLOv4-Pytorch
# Out:
# /content/Complex-YOLOv4-Pytorch

# %% [markdown]
# ## Install needed libraries

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 676.9 MB 3.3 kB/s
# ...
#      |████████████████████████████████| 7.1 MB 31.5 MB/s
# ...
#      |████████████████████████████████| 23.2 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 23.3 MB 1.4 MB/s
# ...
#      |████████████████████████████████| 23.3 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 22.1 MB 73.0 MB/s
# ...
#      |████████████████████████████████| 22.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 17.4 MB 485 kB/s
# ...
#      |████████████████████████████████| 17.3 MB 100 kB/s
# ...
#      |████████████████████████████████| 12.8 MB 36.3 MB/s
# ...
#      |████████████████████████████████| 12.7 MB 23.6 MB/s
# ...
#      |████████████████████████████████| 11.8 MB 46.9 MB/s
# ...
#      |████████████████████████████████| 5.9 MB 37.5 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 44.8 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 28.1 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 41.4 MB/s
# ...

# %%
# !pip3 install vtk==8.1.2
# !pip3 install mayavi
# Out:
# ...
#      |████████████████████████████████| 48.9 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 7.1 MB 4.9 MB/s
# ...
#      |████████████████████████████████| 177 kB 39.0 MB/s
# ...
#      |████████████████████████████████| 194 kB 47.0 MB/s
# ...
#      |████████████████████████████████| 1.3 MB 32.1 MB/s
# ...
#      |████████████████████████████████| 5.1 MB 34.3 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 29.0 MB/s
# ...
#   Created wheel for mayavi: filename=mayavi-4.7.4-cp37-cp37m-linux_x86_64.whl size=13312813 sha256=8d0134dd8bcdd8cd344a84a8174fdc91aeb4b555ce109dc1d575d4b1d09c56a5
#   Stored in directory: /root/.cache/pip/wheels/6e/57/a6/087ccc194de1ef1b2975c0c5c2348423b372da06de1aee8bea
# ...
#   Created wheel for traitsui: filename=traitsui-7.2.1-py3-none-any.whl size=1485989 sha256=f41dd9d97dfc49ea269c755ca14532925fefa1769d06d9eea69246ee714fb130
#   Stored in directory: /root/.cache/pip/wheels/de/d2/e1/7fabe0067f5f5d11fff725170f52f27ba02962ac74f027d628
# ...

# %%
#!pip install PyQt5
# !pip install shapely

# %% [markdown]
# # Run the Model (Testing)

# %%
# %cd /content/Complex-YOLOv4-Pytorch/src
# !python test.py --gpu_idx 0 --pretrained_path /content/Complex-YOLOv4-Pytorch/checkpoints/complex_yolov4_mse_loss.pth --cfgfile /content/Complex-YOLOv4-Pytorch/src/config/cfg/complex_yolov4.cfg --show_image --save_test_output
# Out:
# /content/Complex-YOLOv4-Pytorch/src
# /usr/local/lib/python3.7/dist-packages/traits/etsconfig/etsconfig.py:412: UserWarning: Environment variable "HOME" not set, setting home directory to /tmp
#   % (environment_variable, parent_directory)
# using darknet
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# layer     filters    size              input                output
#     0 conv     32  3 x 3 / 1   608 x 608 x   3   ->   608 x 608 x  32
#     1 conv     64  3 x 3 / 2   608 x 608 x  32   ->   304 x 304 x  64
#     2 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     3 route  1
#     4 conv     64  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  64
#     5 conv     32  1 x 1 / 1   304 x 304 x  64   ->   304 x 304 x  32
#     6 conv     64  3 x 3 / 1   304 x 304 x  32   ->   304 x 304 x  64
#     7 shortcut 4
# ...

# %% [markdown]
# # Evaluation Metric

# %%
# !python evaluate.py --gpu_idx 0 --pretrained_path /content/Complex-YOLOv4-Pytorch/checkpoints/complex_yolov4_mse_loss.pth --cfgfile /content/Complex-YOLOv4-Pytorch/src/config/cfg/complex_yolov4.cfg
# Out:
# using darknet
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
# [INFO] No error, the convolution haven't activate linear
#
#
# -*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=-*=
#
#
# Create the validation dataloader
#
# Start computing mAP...
#
# 100% 28/28 [16:04<00:00, 34.46s/it]
# Computing AP: 100% 3/3 [00:00<00:00, 1380.77it/s]
#
# Done computing mAP...
#
# 	>>>	 Class 0 (Car): precision = 0.9599, recall = 1.0000, AP = 1.0000, f1: 0.9795
# 	>>>	 Class 1 (Ped): precision = 0.7821, recall = 1.0000, AP = 0.8615, f1: 0.8777
# 	>>>	 Class 2 (Cyc): precision = 0.9643, recall = 1.0000, AP = 1.0000, f1: 0.9818
#
# mAP: 0.9538212883860538

# %%
# %cd /content/Complex-YOLOv4-Pytorch/results/complexer_yolov4
# Out:
# /content/Complex-YOLOv4-Pytorch/results/complexer_yolov4

# %%
import cv2
from google.colab.patches import cv2_imshow
#change the range to display the test images 
nlist=[22,26,29,30,32,34,36]
for i in nlist:
  j = str(i)
  img1= cv2.imread("0000"+j+".jpg")
  cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E17850>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E17910>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E17E90>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E179D0>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E17650>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983E17A10>
# <PIL.Image.Image image mode=RGB size=608x791 at 0x7F1983DD9250>

# %% [markdown]
# # References
#
# *   https://github.com/maudzung/Complex-YOLOv4-Pytorch
